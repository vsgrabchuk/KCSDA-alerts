# %% [markdown]
# # Задача
# Написать систему алертов для приложения
#
# Система должна с периодичность каждые 15 минут проверять ключевые метрики:
# - активные пользователи в ленте / мессенджере
# - просмотры
# - лайки
# - CTR
# - количество отправленных сообщений
#
# В случае обнаружения аномального значения, в telegram-чат должен отправиться алерт

# %% [markdown]
# # Решение

# %%
from datetime import timedelta, datetime

import pandas as pd
import numpy as np

import pandahouse as ph

# from airflow.decorators import dag, task
# from airflow.operators.python import get_current_context

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Подключение к БД
connection = {
    'host': 'https://clickhouse.lab.karpov.courses',
    'password': 
    'user': 'student',
    'database': 'simulator'
}
db = 'simulator_20240320'

# Параметры DAG
default_args = {
    'owner': 'v.grabchuk',
    'depends_on_past': False,
    'retries': 2,
    'retry_delay': timedelta(minutes=1),
    'start_date': datetime(2024, 2, 3),
}

# Интервал запуска DAG
schedule_interval = '*/15 * * * *'

# %%
# Временной горизонт для отчёта
days = 8

points = days * 24 * 60 / 15  # Пересчёт в отсчёты
n_prev_points = points + 100  # Поправка на размер окна для расчётов


# Настройка графиков
sns.set(
    font_scale=1.1,  # Размер шрифта
    style='whitegrid',  # Стиль задника, осей
    rc={'figure.figsize': (10, 6)}  # Размер графика
)


time_template = '%Y-%m-%d %H:%M:%S'

# %%
def query(query):
    # Запрос в БД
    return ph.read_clickhouse(query, connection=connection)

# %%
def get_feed_data(n_prev_points):
    # Данные по ленте
    now = pd.Timestamp.now()
    now = now.strftime('%Y-%m-%d %H:%M:%S')
    now = f"'{now}'"
#     context = get_current_context()
#     now = context['ts']
#     now = datetime.strptime(now)
    # now = now.strftime('%Y-%m-%d %H:%M:%S')
#     now = f"'{now}'"
    return query(f"""
        SELECT *
        FROM
        (
            SELECT
                  toStartOfFifteenMinutes(time) AS time_grain
                , uniqExact(user_id) AS uniq_users
                , countIf(action, action='view') AS views
                , countIf(action, action='like') AS likes
                , likes / views AS ctr
            FROM {db}.feed_actions
            WHERE time <= {now}
            GROUP BY time_grain
            ORDER BY time_grain DESC
            LIMIT {n_prev_points} + 1 + 1
        )
        ORDER BY time_grain ASC
    """).iloc[:-1].reset_index(drop=True)

# %%
feed_data_df = get_feed_data(n_prev_points)
feed_data_df
# Out:
#              time_grain  uniq_users  views  likes       ctr
# 0   2024-05-03 11:45:00         592   7660   1629  0.212663
# 1   2024-05-03 12:00:00         607   7473   1566  0.209554
# 2   2024-05-03 12:15:00         591   7195   1558  0.216539
# 3   2024-05-03 12:30:00         611   7684   1649  0.214602
# 4   2024-05-03 12:45:00         599   7669   1651  0.215282
# ..                  ...         ...    ...    ...       ...
# 864 2024-05-12 11:45:00         620   7023   1454  0.207034
# 865 2024-05-12 12:00:00         589   6307   1352  0.214365
# 866 2024-05-12 12:15:00         612   6738   1424  0.211339
# 867 2024-05-12 12:30:00         600   6503   1472  0.226357
# 868 2024-05-12 12:45:00         646   6908   1478  0.213955
#
# [869 rows x 5 columns]

# %%
# Добавление аномалии
k = 0.7

anomaly_df = pd.DataFrame(
    {
        'time_grain': [feed_data_df.iloc[-1].time_grain],
        'uniq_users': [feed_data_df.iloc[-2].uniq_users * k],
        'views': [feed_data_df.iloc[-2].views * k],
        'likes': [feed_data_df.iloc[-2].likes * k],
        'ctr': [feed_data_df.iloc[-2].ctr * k]
    }
)

feed_data_df = pd.concat([feed_data_df.iloc[:-1], anomaly_df], ignore_index=True)
feed_data_df
# Out:
#              time_grain  uniq_users   views   likes       ctr
# 0   2024-05-03 11:45:00       592.0  7660.0  1629.0  0.212663
# 1   2024-05-03 12:00:00       607.0  7473.0  1566.0  0.209554
# 2   2024-05-03 12:15:00       591.0  7195.0  1558.0  0.216539
# 3   2024-05-03 12:30:00       611.0  7684.0  1649.0  0.214602
# 4   2024-05-03 12:45:00       599.0  7669.0  1651.0  0.215282
# ..                  ...         ...     ...     ...       ...
# 864 2024-05-12 11:45:00       620.0  7023.0  1454.0  0.207034
# 865 2024-05-12 12:00:00       589.0  6307.0  1352.0  0.214365
# 866 2024-05-12 12:15:00       612.0  6738.0  1424.0  0.211339
# 867 2024-05-12 12:30:00       600.0  6503.0  1472.0  0.226357
# 868 2024-05-12 12:45:00       420.0  4552.1  1030.4  0.158450
#
# [869 rows x 5 columns]

# %%
def get_messenger_data(n_prev_points):
    # Данные по мессенджеру
    now = pd.Timestamp.now()
    now = now.strftime('%Y-%m-%d %H:%M:%S')
    now = f"'{now}'"
#     context = get_current_context()
#     now = context['ts']
#     now = datetime(now)
#     now = now.strftime('%Y-%d-%m %H:%M:%S')
#     now = f"'{now}'"
    return query(f"""
        SELECT *
        FROM
        (
            SELECT
                  toStartOfFifteenMinutes(time) AS time_grain
                , uniqExact(user_id) AS uniq_users
                , COUNT(receiver_id) AS messages
            FROM {db}.message_actions
            WHERE time <= {now}
            GROUP BY time_grain
            ORDER BY time_grain DESC
            LIMIT {n_prev_points} + 1 + 1
        )
        ORDER BY time_grain ASC
    """).iloc[:-1].reset_index(drop=True)

# %%
messenger_data_df = get_messenger_data(n_prev_points)
messenger_data_df
# Out:
#              time_grain  uniq_users  messages
# 0   2024-05-03 11:45:00         137       186
# 1   2024-05-03 12:00:00         139       171
# 2   2024-05-03 12:15:00         147       190
# 3   2024-05-03 12:30:00         149       193
# 4   2024-05-03 12:45:00         145       181
# ..                  ...         ...       ...
# 864 2024-05-12 11:45:00         147       185
# 865 2024-05-12 12:00:00         141       172
# 866 2024-05-12 12:15:00         138       173
# 867 2024-05-12 12:30:00         146       184
# 868 2024-05-12 12:45:00         153       173
#
# [869 rows x 3 columns]

# %%
def get_anomaly_info(df, metric_col, window_size, kv, use_columns):
    '''
    Возвращает информацию об аномальности точки
    Метод: IQR
    
    Returns:
    --------
    df: pandas.DataFrame
        Структура c информацией по аномальности значений
        anomaly:
            1  - аномалия превышает верхний порог
            0  - аномалии нет
            -1 - аномалия меньше нижнего порога 
    '''    
    q25 = df[metric_col].rolling(window_size-1, closed='left').quantile(0.25)
    q75 = df[metric_col].rolling(window_size-1, closed='left').quantile(0.75)
    iqr = q75 - q25
    
    th_min = q25 - kv*iqr
    th_max = q75 + kv*iqr
        
    # Сглаживание
    th_min = th_min.rolling(window_size, center=True, min_periods=1).mean()
    th_max = th_max.rolling(window_size, center=True, min_periods=1).mean()
    
    df = df[use_columns]
    df['th_min'] = th_min
    df['th_max'] = th_max
    df['anomaly'] = (df[metric_col] < th_min) * (-1) + (df[metric_col] > th_max) * 1
    
    return df

# %%
def get_anomaly_info(
    df, 
    metric_col,
    mean_window_size,
    quantile_window_size,
    use_columns,
    alpha,
    delta=0
):
    '''
    Возвращает информацию об аномальности точки
    Метод: ДИ

    Parameters:
    -----------
    alpha: float
        Левый квантиль для построения ДИ
    delta: float
        Коэффициент для искусственного расширения ДИ

    Returns:
    --------
    df: pandas.DataFrame
        Структура c информацией по аномальности значений
        anomaly:
            1  - аномалия превышает верхний порог
            0  - аномалии нет
            -1 - аномалия меньше нижнего порога 
    '''
    mean = df[metric_col].rolling(mean_window_size).mean()

    high_freq = df[metric_col] - mean

    # CI
    ci_left = high_freq.rolling(quantile_window_size-1, closed='left').quantile(alpha)
    ci_right = high_freq.rolling(quantile_window_size-1, closed='left').quantile(1-alpha)
    # CI modification
    ci_left *= (1 + delta)
    ci_right *= (1 + delta)

    th_min = ci_left + mean
    th_max = ci_right + mean

    df = df[use_columns]

    return df.assign(
        mean=mean,
        high_freq=high_freq,
        ci_left=ci_left,
        ci_right=ci_right,
        th_min=th_min,
        th_max=th_max,
        anomaly=(df[metric_col] < th_min) * (-1) + (df[metric_col] > th_max) * 1
    )

# %%
df = get_anomaly_info( 
    df=feed_data_df, 
    metric_col='uniq_users', 
    mean_window_size=3,
    quantile_window_size=80,
    alpha=0.027,
    use_columns=['time_grain', 'uniq_users']
)
df
# Out:
#              time_grain  uniq_users        mean  high_freq    ci_left  \
# 0   2024-05-03 11:45:00       592.0         NaN        NaN        NaN
# 1   2024-05-03 12:00:00       607.0         NaN        NaN        NaN
# 2   2024-05-03 12:15:00       591.0  596.666667  -5.666667        NaN
# 3   2024-05-03 12:30:00       611.0  603.000000   8.000000        NaN
# 4   2024-05-03 12:45:00       599.0  600.333333  -1.333333        NaN
# ..                  ...         ...         ...        ...        ...
# 864 2024-05-12 11:45:00       620.0  615.666667   4.333333 -55.778667
# 865 2024-05-12 12:00:00       589.0  610.333333 -21.333333 -55.778667
# 866 2024-05-12 12:15:00       612.0  607.000000   5.000000 -55.778667
# 867 2024-05-12 12:30:00       600.0  600.333333  -0.333333 -55.778667
# 868 2024-05-12 12:45:00       480.0  564.000000 -84.000000 -42.454667
#
#       ci_right      th_min      th_max  anomaly
# 0          NaN         NaN         NaN        0
# 1          NaN         NaN         NaN        0
# 2          NaN         NaN         NaN        0
# 3          NaN         NaN         NaN        0
# 4          NaN         NaN         NaN        0
# ..         ...         ...         ...      ...
# 864  41.631333  559.888000  657.298000        0
# 865  41.631333  554.554667  651.964667        0
# 866  41.631333  551.221333  648.631333        0
# 867  41.631333  544.554667  641.964667        0
# 868  41.631333  521.545333  605.631333       -1
#
# [869 rows x 9 columns]

# %%
def get_lineplot(data, x, y, ths=None, title=None, xrotation=20, **kwargs):
    '''
    Возвращает модифицированный lineplot
    
    Parameters:
    -----------
        ths: [th_min, th_max]
            Пороги для отображения на графике
    '''
    
    ax = sns.lineplot(data=data, x=x, y=y, **kwargs)
    if ths is not None:
        th_min = ths[0]
        th_max = ths[1]
        sns.lineplot(data=data, x=x, y=th_min, color='r', linewidth=.5)
        sns.lineplot(data=data, x=x, y=th_max, color='r', linewidth=.5)
    
#     ax.grid()
    if title is not None:
        ax.set_title(title)
    ax.tick_params(axis='x', labelrotation=xrotation)

    return ax

# %%
# Параметры для поиска аномалий
mean_window_size = 3
quantile_window_size = 100
alpha = 0.04

# %%
sns.lineplot(data=df, x='time_grain', y='uniq_users')
sns.lineplot(data=df, x='time_grain', y='mean')
# Out:
# <Axes: xlabel='time_grain', ylabel='uniq_users'>

# %%
metric_col = 'uniq_users'
time_col = 'time_grain'

df = get_anomaly_info(
    df=feed_data_df, 
    metric_col=metric_col, 
    mean_window_size=mean_window_size,
    quantile_window_size=quantile_window_size,
    alpha=alpha,
    use_columns=[time_col, metric_col],
    delta=2.7
)

df = df.iloc[quantile_window_size:]

get_lineplot(
    data=df, 
    x=time_col, 
    y=df['high_freq'], 
    ths=[df['ci_left'], df['ci_right']], 
    title=f'{metric_col} feed'
);

# %%
df.query('anomaly == 1')
# Out:
#              time_grain  uniq_users        mean   high_freq  ci_left  \
# 106 2024-05-04 14:15:00         978  726.333333  251.666667 -129.796
# 107 2024-05-04 14:30:00        1154  918.000000  236.000000 -129.796
#
#        ci_right      th_min       th_max  anomaly
# 106  127.822667  596.537333   854.156000        1
# 107  137.886667  788.204000  1055.886667        1

# %%
df.query('anomaly == -1')
# Out:
#              time_grain  uniq_users        mean   high_freq  ci_left  \
# 108 2024-05-04 14:45:00         596  909.333333 -313.333333 -129.796
# 109 2024-05-04 15:00:00         577  775.666667 -198.666667 -137.344
#
#        ci_right      th_min       th_max  anomaly
# 108  167.881333  779.537333  1077.214667       -1
# 109  167.881333  638.322667   943.548000       -1

# %%
metric_col = 'views'
time_col = 'time_grain'

df = get_anomaly_info(
    df=feed_data_df, 
    metric_col=metric_col, 
    mean_window_size=mean_window_size,
    quantile_window_size=quantile_window_size,
    alpha=alpha,
    use_columns=[time_col, metric_col],
    delta=2.2
)

df = df.iloc[quantile_window_size:]

get_lineplot(
    data=df, 
    x=time_col, 
    y=df['high_freq'], 
    ths=[df['ci_left'], df['ci_right']], 
    title=f'{metric_col} feed'
);

# %%
sns.lineplot(data=df, x=time_col, y=metric_col);

# %%
df.query('anomaly == 1')
# Out:
#              time_grain  views         mean    high_freq   ci_left  ci_right  \
# 106 2024-05-04 14:15:00   9047  7304.666667  1742.333333 -1635.968  1556.352
#
#           th_min       th_max  anomaly
# 106  5668.698667  8861.018667        1

# %%
df.query('anomaly == -1')
# Out:
# Empty DataFrame
# Columns: [time_grain, views, mean, high_freq, ci_left, ci_right, th_min, th_max, anomaly]
# Index: []

# %%
metric_col = 'likes'
time = 'time_grain'

df = get_anomaly_info(
    df=feed_data_df, 
    metric_col=metric_col, 
    mean_window_size=mean_window_size,
    quantile_window_size=quantile_window_size,
    alpha=alpha,
    use_columns=[time_col, metric_col],
    delta=1.8
)

df = df.iloc[quantile_window_size:]

get_lineplot(
    data=df, 
    x=time_col, 
    y=df['high_freq'], 
    ths=[df['ci_left'], df['ci_right']], 
    title=f'{metric_col} feed'
);

# %%
sns.lineplot(data=df, x=time_col, y=metric_col);

# %%
df.query('anomaly == 1')
# Out:
#              time_grain  likes         mean   high_freq     ci_left  ci_right  \
# 106 2024-05-04 14:15:00   1800  1479.666667  320.333333 -354.293333   306.992
#
#           th_min       th_max  anomaly
# 106  1125.373333  1786.658667        1

# %%
metric_col = 'ctr'
time = 'time_grain'

df = get_anomaly_info(
    df=feed_data_df, 
    metric_col=metric_col, 
    mean_window_size=mean_window_size,
    quantile_window_size=quantile_window_size,
    alpha=alpha,
    use_columns=[time_col, metric_col],
    delta=1.6
)

df = df.iloc[quantile_window_size:]

get_lineplot(
    data=df, 
    x=time_col, 
    y=df['high_freq'], 
    ths=[df['ci_left'], df['ci_right']], 
    title=f'{metric_col} feed'
);

# %%
get_lineplot(
    data=df.iloc[-96:], 
    x=time_col, 
    y=df[metric_col], 
    ths=[df['th_min'], df['th_max']], 
    title=f'{metric_col} feed'
);

# %%
metric_col = 'uniq_users'
time = 'time_grain'

df = get_anomaly_info(
    df=messenger_data_df, 
    metric_col=metric_col, 
    mean_window_size=mean_window_size,
    quantile_window_size=quantile_window_size,
    alpha=alpha,
    use_columns=[time_col, metric_col],
    delta=2
)

df = df.iloc[quantile_window_size:]

get_lineplot(
    data=df, 
    x=time_col, 
    y=df['high_freq'], 
    ths=[df['ci_left'], df['ci_right']], 
    title=f'{metric_col} messenger'
);

# %%
sns.lineplot(data=df, x=time_col, y=metric_col);

# %%
metric_col = 'messages'
time = 'time_grain'

df = get_anomaly_info(
    df=messenger_data_df, 
    metric_col=metric_col, 
    mean_window_size=mean_window_size,
    quantile_window_size=quantile_window_size,
    alpha=alpha,
    use_columns=[time_col, metric_col],
    delta=1.6
)

df = df.iloc[quantile_window_size:]

plot = get_lineplot(
    data=df, 
    x=time_col, 
    y=df['high_freq'], 
    ths=[df['ci_left'], df['ci_right']], 
    title=f'{metric_col}'
);

# %%
sns.lineplot(data=df, x=time_col, y=metric_col);

# %%
def is_anomaly(df, anomaly_flag_col='anomaly'):
    return bool(df.iloc[-1][anomaly_flag_col])

# %%
is_anomaly(df)
# Out:
# False

# %% [markdown]
# # Бот

# %%
import telegram
import io

# %%
my_token = 
bot = telegram.Bot(token=my_token)

# %%
chat_id =

# %%
def report_message(bot, chat_id, text):
    # Отправка сообщения
    bot.sendMessage(chat_id=chat_id, text=text)

# %%
def report_image(bot, chat_id, plot):
    # Отправка изображения
    buffer = io.BytesIO()
    plot.figure.savefig(buffer, format='png', bbox_inches='tight')
    buffer.seek(0)
    bot.sendPhoto(chat_id=chat_id, photo=buffer)
    plt.close()

# %%
def check_metric(df, metric_col, time_col, delta=2, round_digits=2, plot_title=None): 
    time = pd.Timestamp.now()
    time = time.strftime('%Y-%m-%d %H:%M:%S')
    # context = get_current_context()
    # now = context['ts']
    # now = datetime.fromisoformat(now)
    # time = now - timedelta(minutes=15)
    # time = time.strftime(time_template)

    df = get_anomaly_info(
        df=df, 
        metric_col=metric_col, 
        mean_window_size=mean_window_size,
        quantile_window_size=quantile_window_size,
        alpha=alpha,
        use_columns=[time_col, metric_col],
        delta=delta
    )

    df = df.iloc[quantile_window_size:]

    if is_anomaly(df):
        text = f'''ANOMALY ALERT! 
{time}
----------------------------------------------------
Метрика: {plot_title}

Текущее значение: {round(df[metric_col].iloc[-1], round_digits)}
rolling_mean: {round(df['mean'].iloc[-1], round_digits)}
Отклонение: {round(df['high_freq'].iloc[-1], round_digits)}
----------------------------------------------------
Дашборд: https://superset.lab.karpov.courses/superset/dashboard/5423/

@boss
        '''

        plot = get_lineplot(
            data=df, 
            x=time_col, 
            y=df['high_freq'], 
            ths=[df['ci_left'], df['ci_right']], 
            title=plot_title
        );

        report_message(bot, chat_id, text)
        report_image(bot, chat_id, plot)

    return df

# %%
time_col = 'time_grain'

# %%
feed_data_df
# Out:
#              time_grain  uniq_users  views  likes       ctr
# 0   2024-05-03 11:45:00         592   7660   1629  0.212663
# 1   2024-05-03 12:00:00         607   7473   1566  0.209554
# 2   2024-05-03 12:15:00         591   7195   1558  0.216539
# 3   2024-05-03 12:30:00         611   7684   1649  0.214602
# 4   2024-05-03 12:45:00         599   7669   1651  0.215282
# ..                  ...         ...    ...    ...       ...
# 864 2024-05-12 11:45:00         620   7023   1454  0.207034
# 865 2024-05-12 12:00:00         589   6307   1352  0.214365
# 866 2024-05-12 12:15:00         612   6738   1424  0.211339
# 867 2024-05-12 12:30:00         600   6503   1472  0.226357
# 868 2024-05-12 12:45:00         646   6908   1478  0.213955
#
# [869 rows x 5 columns]

# %%
# feed
deltas = (
    2.5,  # uniq_users
    2.2,  # views
    1.8,  # likes
    1.9   # ctr
)
for metric_col, delta in zip(['uniq_users', 'views', 'likes', 'ctr'], deltas):
    _ = check_metric(
        df=feed_data_df, 
        metric_col=metric_col,
        time_col=time_col,
        delta=delta,
        plot_title=f'feed {metric_col}'
    )
